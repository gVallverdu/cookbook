# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
df = pd.DataFrame({k: np.random.random(100) for k in "abc"})

# %%
sns.pairplot(data=df, corner=True)

# %%
sns.pairplot(data=df, corner=True, grid_kws=dict(despine=False))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-57b99bef2bc1> in <module>
# ----> 1 sns.pairplot(data=df, corner=True, grid_kws=dict(despine=False))
#
# ~/opt/miniconda3/envs/curv/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2107     if grid.square_grid:
#    2108         if diag_kind == "hist":
# -> 2109             grid.map_diag(plt.hist, **diag_kws)
#    2110         elif diag_kind == "kde":
#    2111             diag_kws.setdefault("shade", True)
#
# ~/opt/miniconda3/envs/curv/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1440                         if self._corner:
#    1441                             ax.yaxis.set_visible(False)
# ...
